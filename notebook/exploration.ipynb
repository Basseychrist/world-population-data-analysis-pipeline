# %% [markdown]
# # World Population Data Analysis
# In this notebook, we'll perform an exploratory data analysis (EDA) on the global population dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to the Python path so we can import our modules
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from analysis import (
    exploratory_insights, 
    display_density_extremes,
    plot_top_populated_countries_2023, 
    plot_population_in_continents_2023,
    plot_continent_population_timeline,
    plot_continent_population_density,
    plot_pearson_correlation
)

# Set up matplotlib style
sns.set_theme(style="whitegrid", palette="muted")
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data
# Read the cleaned dataset generated by our pipeline.

# %%
df = pd.read_csv('../data/processed/world_population_data_clean.csv')
df.head()
# Out:
#    rank cca3        country      continent  2023_population  2022_population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
#
#    2020_population  2015_population  2010_population  2000_population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990_population  1980_population  1970_population  area_(km²)  \
# ...

# %% [markdown]
# ## 2. Exploratory Insights
# Print the data shape, overview, information, summaries and check for null values.

# %%
exploratory_insights(df)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS
# ...
#
# 1. Data Shape:
# Rows: 234, Columns: 17
#
# 2. Data Overview (First 5 Rows):
#    rank cca3        country      continent  2023_population  2022_population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
#
#    2020_population  2015_population  2010_population  2000_population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# ...

# %% [markdown]
# ## 3. Visualization Palette
# Let's dive into plotting the demographic information requested.
#
# ### 3.1 Top Populated Countries in 2023

# %%
# Plot the top populated countries in 2023
plot_top_populated_countries_2023(df, top_n=10)
# Out:
# c:\world-population-data-analysis-pipeline\src\analysis.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_countries, x='2023_population', y='country', palette='viridis')

# %% [markdown]
# ### 3.2 Total Population by Continent in 2023

# %%
# Show the breakdown of population across Asia, Africa, Europe, North America, South America, and Oceania
plot_population_in_continents_2023(df)
# Out:
# c:\world-population-data-analysis-pipeline\src\analysis.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=continent_pop, x='continent', y='2023_population', palette='magma')

# %% [markdown]
# ### 3.3 Continent-wise Population Timeline (1970 to 2023)

# %%
# Plot the timeline of populations for each continent
plot_continent_population_timeline(df)

# %% [markdown]
# ### 3.4 Continent-wise Population Density and Extremes
# Explore the density (km²) across continents and identify the most and least densely populated countries.

# %%
# Compare continent density spreads
plot_continent_population_density(df)

# Print density extremes: most and least densely populated countries
display_density_extremes(df)
# Out:
# c:\world-population-data-analysis-pipeline\src\analysis.py:111: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='continent', y='density_(km²)', palette='Set2')
# ...
# DENSITY EXTREMES
# ...
# Most Densely Populated: Macau (21403 ppl/km²)
# Least Densely Populated: Greenland (0 ppl/km²)
# ...

# %% [markdown]
# ### 3.5 Pearson Correlation of Features
# Analyze linear correlations between numerical variables such as growth rates, area and population counts.

# %%
# Plot the Pearson correlation heatmap
plot_pearson_correlation(df)
